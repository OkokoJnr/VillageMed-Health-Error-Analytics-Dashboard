# %%
import pandas as pd

# %%
#Read the dataset
frame1 = pd.read_csv("../raw_data/medical_error_records.csv")
frame2 = pd.read_csv("../raw_data/medical_error_records_2.csv")

# %%
frame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   patient_id              277 non-null    int64
#  1   hospital_facility_type  277 non-null    object
#  2   state                   277 non-null    object
#  3   country                 277 non-null    object
#  4   reporting_staff_role    277 non-null    object
#  5   patient_age             277 non-null    int64
#  6   patient_gender          277 non-null    object
#  7   error_type              277 non-null    object
#  8   error_subtype           277 non-null    object
#  9   department              277 non-null    object
#  10  severity_level          277 non-null    object
#  11  outcome                 277 non-null    object
#  12  detection_method        277 non-null    object
#  13  contributing_factor     277 non-null    object
# ...

# %%
frame1.shape
# Out:
# (277, 16)

# %%
frame1.head()
# Out:
#    patient_id hospital_facility_type  state  country reporting_staff_role  \
# 0           1      Tertiary Hospital   Kano  Nigeria                Nurse
# 1           2       General Hospital  Lagos  Nigeria                Nurse
# 2           3      Teaching Hospital    FCT  Nigeria           Pharmacist
# 3           4      Teaching Hospital    Imo  Nigeria                Nurse
# 4           5      Teaching Hospital    Edo  Nigeria               Doctor
#
#    patient_age patient_gender           error_type             error_subtype  \
# 0           43           Male     Medication Error              Omitted Dose
# 1           59         Female  Documentation Error       Wrong Patient Chart
# 2           26         Female  Documentation Error           Illegible Order
# 3           37         Female     Surgical Mistake             Post-op Bleed
# 4            0           Male     Diagnostic Error  Result Misinterpretation
#
# ...

# %%
frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patient_id            277 non-null    int64
#  1   facility_type         277 non-null    object
#  2   state                 277 non-null    object
#  3   country               277 non-null    object
#  4   reporting_staff_role  277 non-null    object
#  5   patient_age           277 non-null    int64
#  6   patient_gender        277 non-null    object
#  7   error_type            277 non-null    object
#  8   error_subtype         277 non-null    object
#  9   department            277 non-null    object
#  10  severity_level        277 non-null    object
#  11  outcome               277 non-null    object
#  12  detection_method      277 non-null    object
#  13  contributing_factor   277 non-null    object
#  14  report_source         277 non-null    object
# ...

# %%
frame2.shape
# Out:
# (277, 16)

# %%
frame2.head()
# Out:
#    patient_id        facility_type          state   country  \
# 0           1     General Hospital          Mbale  Tanzania
# 1           2    Teaching Hospital        Kampala     Kenya
# 2           3  Specialist Hospital        Nairobi    Uganda
# 3           4    Teaching Hospital         Dodoma    Uganda
# 4           5     General Hospital  Dar es Salaam    Uganda
#
#   reporting_staff_role  patient_age patient_gender              error_type  \
# 0           Pharmacist            1           Male  Device/Equipment Error
# 1        Lab Scientist           40           Male       Transfusion Error
# 2        Lab Scientist           42         Female        Medication Error
# 3               Doctor           59           Male        Surgical Mistake
# 4                Nurse           48           Male        Surgical Mistake
#
#        error_subtype  department severity_level         outcome  \
# 0  Calibration Error    Pharmacy          Minor  Permanent Harm
# ...

# %%
#checking for duplicates in both datasets
frame1.duplicated().sum()
frame2.duplicated().sum()
# Out:
# 0

# %%
#check for missing values
frame1.isnull().sum()
frame2.isnull().sum()
# Out:
# patient_id              0
# facility_type           0
# state                   0
# country                 0
# reporting_staff_role    0
# patient_age             0
# patient_gender          0
# error_type              0
# error_subtype           0
# department              0
# severity_level          0
# outcome                 0
# detection_method        0
# contributing_factor     0
# report_source           0
# corrective_action       0
# dtype: int64

# %%
frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patient_id            277 non-null    int64
#  1   facility_type         277 non-null    object
#  2   state                 277 non-null    object
#  3   country               277 non-null    object
#  4   reporting_staff_role  277 non-null    object
#  5   patient_age           277 non-null    int64
#  6   patient_gender        277 non-null    object
#  7   error_type            277 non-null    object
#  8   error_subtype         277 non-null    object
#  9   department            277 non-null    object
#  10  severity_level        277 non-null    object
#  11  outcome               277 non-null    object
#  12  detection_method      277 non-null    object
#  13  contributing_factor   277 non-null    object
#  14  report_source         277 non-null    object
# ...

# %%
#rename all columns in frame2 to match frame1
frame2.columns = frame1.columns

# %%
frame1.head()
# Out:
#    patient_id hospital_facility_type  state  country reporting_staff_role  \
# 0           1      Tertiary Hospital   Kano  Nigeria                Nurse
# 1           2       General Hospital  Lagos  Nigeria                Nurse
# 2           3      Teaching Hospital    FCT  Nigeria           Pharmacist
# 3           4      Teaching Hospital    Imo  Nigeria                Nurse
# 4           5      Teaching Hospital    Edo  Nigeria               Doctor
#
#    patient_age patient_gender           error_type             error_subtype  \
# 0           43           Male     Medication Error              Omitted Dose
# 1           59         Female  Documentation Error       Wrong Patient Chart
# 2           26         Female  Documentation Error           Illegible Order
# 3           37         Female     Surgical Mistake             Post-op Bleed
# 4            0           Male     Diagnostic Error  Result Misinterpretation
#
# ...

# %%
frame2.head()
# Out:
#    patient_id hospital_facility_type          state   country  \
# 0           1       General Hospital          Mbale  Tanzania
# 1           2      Teaching Hospital        Kampala     Kenya
# 2           3    Specialist Hospital        Nairobi    Uganda
# 3           4      Teaching Hospital         Dodoma    Uganda
# 4           5       General Hospital  Dar es Salaam    Uganda
#
#   reporting_staff_role  patient_age patient_gender              error_type  \
# 0           Pharmacist            1           Male  Device/Equipment Error
# 1        Lab Scientist           40           Male       Transfusion Error
# 2        Lab Scientist           42         Female        Medication Error
# 3               Doctor           59           Male        Surgical Mistake
# 4                Nurse           48           Male        Surgical Mistake
#
#        error_subtype  department severity_level         outcome  \
# 0  Calibration Error    Pharmacy          Minor  Permanent Harm
# ...

# %%
#export cleaned datasets to csv files
frame1.to_csv("../cleaned_data/cleaned_medical_error_records_Nigeria.csv", index=False)
frame2.to_csv("../cleaned_data/cleaned_medical_error_records_Others.csv", index=False)
